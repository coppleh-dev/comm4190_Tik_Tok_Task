# %% [markdown]
# **Conclusion**
#
# Our results show us that support for Brooke (concept 2) is more numerous than support for Tana (concept 1), while there is also hate on both sides (neither) or 0,0 on the score.
# ![Screen Shot 2025-12-03 at 2.07.43 PM.png](attachment:3a57dab6-a5dc-4922-9943-f13943e764fc.png)

# %% [markdown]
# Our results showed us that, again, there were more likes for Concept 2 (support for Brooke) than for Tana and, almost equally, support for neither of them/irrelevant comments.
# ![Screen Shot 2025-12-03 at 2.10.43 PM.png](attachment:ba179053-1e6a-4ae8-a863-27823cec205b.png)

# %% [markdown]
# This surprised us as we hypothesized there would be more support for Tana—she is a bigger creator and Brooke is a very controversial character. In a way, Brooke is "canceled" and Tana *canceled* the show because there was an overwhelming amount of hate towards Brooke. Tana then proposed she would take the videos down from the show (Brooke's main source of income from monetizatin) and facts **suprisingly* rallied around Brooke, from this video. I think this shows us that despite an overarching debate leaning towards one side (in favor of Tana to defend her podcast) there is nuance in HOW she is ending her podcast and the impact it has on Brooke as her business partner. I believe this challenges the notion of cancel-culture as a nuance-lacking phenomena that villainizes someone with no sympathy and, at the same time, idolizes figures they do not really know.
